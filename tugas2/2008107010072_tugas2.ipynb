# %% [markdown]
# ## Tugas 2 Visi Komputer
#
# Bayangkan anda bekerja sebagai anggota dari CSI (Crime Scene Investigation). Anda bekerja sebagai ahli cyber forensic. Kali ini, anda mendapat pekerjaan untuk mengidentifikasikan gambar tato seorang kriminal yang didapat dari CCTV. Namun identitas orang tersebut belum dapat diketahui. Anda memiliki data gambar-gambar orang tersangka, ada yang memiliki tato dan ada juga yang tidak memiliki tato. Jadi tugas anda di sini, ialah mengidentifikasikan siapakah kriminal yang dimaksud berdasarkan data gambar-gambar yang dimiliki.
#
# Panduan:
#
# Data gambar boleh disimpan di dalam folder, atau di dalam basis data. Simpan image descriptor untuk semua file gambar Baca semua data gambar dan temukan padanan antara descriptor dari image query dan descriptor dari semua gambar Gambar-gambar tato bisa diambil dari website kaggle.com atau website lainnya yang memiliki dataset gambar tato.
#
# Sertakan link google drive untuk mendownload gambar-gambar yang anda gunakan.
#
# Jawab
#
# Nama : Khairul Umam Albi
#
# NPM : 2008107010072
#
# Untuk mengerjakan tugas ini saya telah menyiapkan 10 foto tersangka dan 1 foto tato. Link Google Drive : https://drive.google.com/drive/folders/1hJvavApoFadDcCWW5WS56A3_fYugNYiA?usp=sharing

# %%
import numpy as np 
import cv2 
from matplotlib import pyplot as plt

# %%
# Read the training and query images
query_img = cv2.imread('gambar/target.jpg')

train_img = cv2.imread('gambar/p1.jpg') 

# Convert the images to grayscale 
query_img_gray = cv2.cvtColor(query_img,cv2.COLOR_BGR2GRAY) 
train_img_gray = cv2.cvtColor(train_img, cv2.COLOR_BGR2GRAY) 

# Initialize the ORB detector algorithm 
orb = cv2.ORB_create() 

# Detect keypoints (features) cand calculate the descriptors
query_keypoints, query_descriptors = orb.detectAndCompute(query_img_gray,None) 
train_keypoints, train_descriptors = orb.detectAndCompute(train_img_gray,None) 

# Match the keypoints
matcher = cv2.BFMatcher() 
matches = matcher.match(query_descriptors,train_descriptors) 

# Draw the keypoint matches on the output image
output_img = cv2.drawMatches(query_img, query_keypoints, 
train_img, train_keypoints, matches[:20],None) 

output_img = cv2.resize(output_img, (1200,650)) 

# Save the final image 
cv2.imwrite("imwrite/feature_matching_result.jpg", output_img) 

cv2.imshow('imwrite/Feature matching dengan Brute force', output_img)
#plt.imshow(output_img),plt.show()

# Close OpenCV upon keypress
cv2.waitKey(0)
cv2.destroyAllWindows()


# Save the final image 
output_img = cv2.cvtColor(output_img, cv2.COLOR_BGR2RGB)
plt.imshow(output_img),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x1eb00424e50>, None)

# %%
# Read the training and query images
query_img = cv2.imread('gambar/target.jpg')

train_img = cv2.imread('gambar/p2.jpg') 

# Convert the images to grayscale 
query_img_gray = cv2.cvtColor(query_img,cv2.COLOR_BGR2GRAY) 
train_img_gray = cv2.cvtColor(train_img, cv2.COLOR_BGR2GRAY) 

# Initialize the ORB detector algorithm 
orb = cv2.ORB_create() 

# Detect keypoints (features) cand calculate the descriptors
query_keypoints, query_descriptors = orb.detectAndCompute(query_img_gray,None) 
train_keypoints, train_descriptors = orb.detectAndCompute(train_img_gray,None) 

# Match the keypoints
matcher = cv2.BFMatcher() 
matches = matcher.match(query_descriptors,train_descriptors) 

# Draw the keypoint matches on the output image
output_img = cv2.drawMatches(query_img, query_keypoints, 
train_img, train_keypoints, matches[:20],None) 

output_img = cv2.resize(output_img, (1200,650)) 

# Save the final image 
cv2.imwrite("imwrite/feature_matching_result2.jpg", output_img) 

cv2.imshow('imwrite/Feature matching dengan Brute force', output_img)
#plt.imshow(output_img),plt.show()

# Close OpenCV upon keypress
cv2.waitKey(0)
cv2.destroyAllWindows()


# Save the final image 
output_img = cv2.cvtColor(output_img, cv2.COLOR_BGR2RGB)
plt.imshow(output_img),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x1eb0048cbe0>, None)

# %%
# Read the training and query images
query_img = cv2.imread('gambar/target.jpg')

train_img = cv2.imread('gambar/p3.jpg') 

# Convert the images to grayscale 
query_img_gray = cv2.cvtColor(query_img,cv2.COLOR_BGR2GRAY) 
train_img_gray = cv2.cvtColor(train_img, cv2.COLOR_BGR2GRAY) 

# Initialize the ORB detector algorithm 
orb = cv2.ORB_create() 

# Detect keypoints (features) cand calculate the descriptors
query_keypoints, query_descriptors = orb.detectAndCompute(query_img_gray,None) 
train_keypoints, train_descriptors = orb.detectAndCompute(train_img_gray,None) 

# Match the keypoints
matcher = cv2.BFMatcher() 
matches = matcher.match(query_descriptors,train_descriptors) 

# Draw the keypoint matches on the output image
output_img = cv2.drawMatches(query_img, query_keypoints, 
train_img, train_keypoints, matches[:20],None) 

output_img = cv2.resize(output_img, (1200,650)) 

# Save the final image 
cv2.imwrite("imwrite/feature_matching_result3.jpg", output_img) 

cv2.imshow('imwrite/Feature matching dengan Brute force', output_img)
#plt.imshow(output_img),plt.show()

# Close OpenCV upon keypress
cv2.waitKey(0)
cv2.destroyAllWindows()


# Save the final image 
output_img = cv2.cvtColor(output_img, cv2.COLOR_BGR2RGB)
plt.imshow(output_img),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x1eb004fb220>, None)

# %%
# Read the training and query images
query_img = cv2.imread('gambar/target.jpg')

train_img = cv2.imread('gambar/p4.jpg') 

# Convert the images to grayscale 
query_img_gray = cv2.cvtColor(query_img,cv2.COLOR_BGR2GRAY) 
train_img_gray = cv2.cvtColor(train_img, cv2.COLOR_BGR2GRAY) 

# Initialize the ORB detector algorithm 
orb = cv2.ORB_create() 

# Detect keypoints (features) cand calculate the descriptors
query_keypoints, query_descriptors = orb.detectAndCompute(query_img_gray,None) 
train_keypoints, train_descriptors = orb.detectAndCompute(train_img_gray,None) 

# Match the keypoints
matcher = cv2.BFMatcher() 
matches = matcher.match(query_descriptors,train_descriptors) 

# Draw the keypoint matches on the output image
output_img = cv2.drawMatches(query_img, query_keypoints, 
train_img, train_keypoints, matches[:20],None) 

output_img = cv2.resize(output_img, (1200,650)) 

# Save the final image 
cv2.imwrite("imwrite/feature_matching_result4.jpg", output_img) 

cv2.imshow('imwrite/Feature matching dengan Brute force', output_img)
#plt.imshow(output_img),plt.show()

# Close OpenCV upon keypress
cv2.waitKey(0)
cv2.destroyAllWindows()


# Save the final image 
output_img = cv2.cvtColor(output_img, cv2.COLOR_BGR2RGB)
plt.imshow(output_img),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x1eb0055c7f0>, None)

# %%
# Read the training and query images
query_img = cv2.imread('gambar/target.jpg')

train_img = cv2.imread('gambar/p5.jpg') 

# Convert the images to grayscale 
query_img_gray = cv2.cvtColor(query_img,cv2.COLOR_BGR2GRAY) 
train_img_gray = cv2.cvtColor(train_img, cv2.COLOR_BGR2GRAY) 

# Initialize the ORB detector algorithm 
orb = cv2.ORB_create() 

# Detect keypoints (features) cand calculate the descriptors
query_keypoints, query_descriptors = orb.detectAndCompute(query_img_gray,None) 
train_keypoints, train_descriptors = orb.detectAndCompute(train_img_gray,None) 

# Match the keypoints
matcher = cv2.BFMatcher() 
matches = matcher.match(query_descriptors,train_descriptors) 

# Draw the keypoint matches on the output image
output_img = cv2.drawMatches(query_img, query_keypoints, 
train_img, train_keypoints, matches[:20],None) 

output_img = cv2.resize(output_img, (1200,650)) 

# Save the final image 
cv2.imwrite("imwrite/feature_matching_result5.jpg", output_img) 

cv2.imshow('imwrite/Feature matching dengan Brute force', output_img)
#plt.imshow(output_img),plt.show()

# Close OpenCV upon keypress
cv2.waitKey(0)
cv2.destroyAllWindows()


# Save the final image 
output_img = cv2.cvtColor(output_img, cv2.COLOR_BGR2RGB)
plt.imshow(output_img),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x1eb005c0e80>, None)

# %%
# Read the training and query images
query_img = cv2.imread('gambar/target.jpg')

train_img = cv2.imread('gambar/p6.jpg') 

# Convert the images to grayscale 
query_img_gray = cv2.cvtColor(query_img,cv2.COLOR_BGR2GRAY) 
train_img_gray = cv2.cvtColor(train_img, cv2.COLOR_BGR2GRAY) 

# Initialize the ORB detector algorithm 
orb = cv2.ORB_create() 

# Detect keypoints (features) cand calculate the descriptors
query_keypoints, query_descriptors = orb.detectAndCompute(query_img_gray,None) 
train_keypoints, train_descriptors = orb.detectAndCompute(train_img_gray,None) 

# Match the keypoints
matcher = cv2.BFMatcher() 
matches = matcher.match(query_descriptors,train_descriptors) 

# Draw the keypoint matches on the output image
output_img = cv2.drawMatches(query_img, query_keypoints, 
train_img, train_keypoints, matches[:20],None) 

output_img = cv2.resize(output_img, (1200,650)) 

# Save the final image 
cv2.imwrite("imwrite/feature_matching_result6.jpg", output_img) 

cv2.imshow('imwrite/Feature matching dengan Brute force', output_img)
#plt.imshow(output_img),plt.show()

# Close OpenCV upon keypress
cv2.waitKey(0)
cv2.destroyAllWindows()


# Save the final image 
output_img = cv2.cvtColor(output_img, cv2.COLOR_BGR2RGB)
plt.imshow(output_img),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x1eb0062d4c0>, None)

# %%
# Read the training and query images
query_img = cv2.imread('gambar/target.jpg')

train_img = cv2.imread('gambar/p7.jpg') 

# Convert the images to grayscale 
query_img_gray = cv2.cvtColor(query_img,cv2.COLOR_BGR2GRAY) 
train_img_gray = cv2.cvtColor(train_img, cv2.COLOR_BGR2GRAY) 

# Initialize the ORB detector algorithm 
orb = cv2.ORB_create() 

# Detect keypoints (features) cand calculate the descriptors
query_keypoints, query_descriptors = orb.detectAndCompute(query_img_gray,None) 
train_keypoints, train_descriptors = orb.detectAndCompute(train_img_gray,None) 

# Match the keypoints
matcher = cv2.BFMatcher() 
matches = matcher.match(query_descriptors,train_descriptors) 

# Draw the keypoint matches on the output image
output_img = cv2.drawMatches(query_img, query_keypoints, 
train_img, train_keypoints, matches[:20],None) 

output_img = cv2.resize(output_img, (1200,650)) 

# Save the final image 
cv2.imwrite("imwrite/feature_matching_result7.jpg", output_img) 

cv2.imshow('imwrite/Feature matching dengan Brute force', output_img)
#plt.imshow(output_img),plt.show()

# Close OpenCV upon keypress
cv2.waitKey(0)
cv2.destroyAllWindows()


# Save the final image 
output_img = cv2.cvtColor(output_img, cv2.COLOR_BGR2RGB)
plt.imshow(output_img),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x1eb01ddfaf0>, None)

# %%
# Read the training and query images
query_img = cv2.imread('gambar/target.jpg')

train_img = cv2.imread('gambar/p8.jpg') 

# Convert the images to grayscale 
query_img_gray = cv2.cvtColor(query_img,cv2.COLOR_BGR2GRAY) 
train_img_gray = cv2.cvtColor(train_img, cv2.COLOR_BGR2GRAY) 

# Initialize the ORB detector algorithm 
orb = cv2.ORB_create() 

# Detect keypoints (features) cand calculate the descriptors
query_keypoints, query_descriptors = orb.detectAndCompute(query_img_gray,None) 
train_keypoints, train_descriptors = orb.detectAndCompute(train_img_gray,None) 

# Match the keypoints
matcher = cv2.BFMatcher() 
matches = matcher.match(query_descriptors,train_descriptors) 

# Draw the keypoint matches on the output image
output_img = cv2.drawMatches(query_img, query_keypoints, 
train_img, train_keypoints, matches[:20],None) 

output_img = cv2.resize(output_img, (1200,650)) 

# Save the final image 
cv2.imwrite("imwrite/feature_matching_result8.jpg", output_img) 

cv2.imshow('imwrite/Feature matching dengan Brute force', output_img)
#plt.imshow(output_img),plt.show()

# Close OpenCV upon keypress
cv2.waitKey(0)
cv2.destroyAllWindows()


# Save the final image 
output_img = cv2.cvtColor(output_img, cv2.COLOR_BGR2RGB)
plt.imshow(output_img),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x1eb01e4f0d0>, None)

# %%
# Read the training and query images
query_img = cv2.imread('gambar/target.jpg')

train_img = cv2.imread('gambar/p9.jpg') 

# Convert the images to grayscale 
query_img_gray = cv2.cvtColor(query_img,cv2.COLOR_BGR2GRAY) 
train_img_gray = cv2.cvtColor(train_img, cv2.COLOR_BGR2GRAY) 

# Initialize the ORB detector algorithm 
orb = cv2.ORB_create() 

# Detect keypoints (features) cand calculate the descriptors
query_keypoints, query_descriptors = orb.detectAndCompute(query_img_gray,None) 
train_keypoints, train_descriptors = orb.detectAndCompute(train_img_gray,None) 

# Match the keypoints
matcher = cv2.BFMatcher() 
matches = matcher.match(query_descriptors,train_descriptors) 

# Draw the keypoint matches on the output image
output_img = cv2.drawMatches(query_img, query_keypoints, 
train_img, train_keypoints, matches[:20],None) 

output_img = cv2.resize(output_img, (1200,650)) 

# Save the final image 
cv2.imwrite("imwrite/feature_matching_result9.jpg", output_img) 

cv2.imshow('imwrite/Feature matching dengan Brute force', output_img)
#plt.imshow(output_img),plt.show()

# Close OpenCV upon keypress
cv2.waitKey(0)
cv2.destroyAllWindows()


# Save the final image 
output_img = cv2.cvtColor(output_img, cv2.COLOR_BGR2RGB)
plt.imshow(output_img),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x1eb027f9b80>, None)

# %%
# Read the training and query images
query_img = cv2.imread('gambar/target.jpg')

train_img = cv2.imread('gambar/p10.jpg') 

# Convert the images to grayscale 
query_img_gray = cv2.cvtColor(query_img,cv2.COLOR_BGR2GRAY) 
train_img_gray = cv2.cvtColor(train_img, cv2.COLOR_BGR2GRAY) 

# Initialize the ORB detector algorithm 
orb = cv2.ORB_create() 

# Detect keypoints (features) cand calculate the descriptors
query_keypoints, query_descriptors = orb.detectAndCompute(query_img_gray,None) 
train_keypoints, train_descriptors = orb.detectAndCompute(train_img_gray,None) 

# Match the keypoints
matcher = cv2.BFMatcher() 
matches = matcher.match(query_descriptors,train_descriptors) 

# Draw the keypoint matches on the output image
output_img = cv2.drawMatches(query_img, query_keypoints, 
train_img, train_keypoints, matches[:20],None) 

output_img = cv2.resize(output_img, (1200,650)) 

# Save the final image 
cv2.imwrite("imwrite/feature_matching_result10.jpg", output_img) 

cv2.imshow('imwrite/Feature matching dengan Brute force', output_img)
#plt.imshow(output_img),plt.show()

# Close OpenCV upon keypress
cv2.waitKey(0)
cv2.destroyAllWindows()


# Save the final image 
output_img = cv2.cvtColor(output_img, cv2.COLOR_BGR2RGB)
plt.imshow(output_img),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x1eb02862c70>, None)
